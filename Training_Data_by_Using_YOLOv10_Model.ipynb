# %% [markdown]
# <a href="https://colab.research.google.com/github/MdSohidUllahChowdhury/Rose-leaf-Disease-Detection-App/blob/main/Training_Data_by_Using_YOLOv10_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20332, done.
# remote: Counting objects: 100% (2446/2446), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 20332 (delta 2317), reused 2197 (delta 2196), pack-reused 17886 (from 1)
# Receiving objects: 100% (20332/20332), 11.14 MiB | 16.78 MiB/s, done.
# Resolving deltas: 100% (14337/14337), done.

# %%
# %cd /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10
# Out:
# /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10

# %%
# !pwd
# Out:
# /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.4/881.4 kB 23.0 MB/s eta 0:00:00
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/weights/yolov10n.pt
# Downloaded /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/weights/yolov10s.pt
# Downloaded /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/weights/yolov10m.pt
# Downloaded /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/weights/yolov10b.pt
# Downloaded /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/weights/yolov10x.pt

# %%
# !unzip Dataset.zip
# Out:
# Archive:  Dataset.zip
#    creating: Dataset/
#    creating: Dataset/BlackSpot/
#    creating: Dataset/BlackSpot/train/
#    creating: Dataset/BlackSpot/train/images/
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-10-_jpg.rf.1913899c49ffb608c2ab2fabb7e62caf.jpg
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-101-_jpg.rf.6fd9e492de0e22670987874d18cdad6e.jpg
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-102-_jpg.rf.be4cde2fd32f37ced02199ef90e46e01.jpg
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-103-_jpg.rf.759173e01a6d88da979d926c1226f8ec.jpg
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-104-_jpg.rf.79c6543eed3b570da32f92011965296c.jpg
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-107-_jpg.rf.11bedf023e2b8a0c4c4d2c60d00da9a0.jpg
#   inflating: Dataset/BlackSpot/train/images/Black-Spot-108-_jpg.rf.1ce120a433bc20d22e247e13751a3557.jpg
# ...

# %%
# !yolo task=detect mode=train epochs=150 batch=16 plots=True model=weights/yolov10n.pt data=data.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/runs/detect/train/weights/best.pt source=BlackSpot.jpg
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 /content/drive/MyDrive/RLDD_by_Using_Deep_Learning/TrainingData/yolov10/BlackSpot.jpg: 640x384 6 Black Spots, 46.2ms
# Speed: 2.3ms preprocess, 46.2ms inference, 42.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
